# %% [markdown]
# ## Write Code in Empty cells don't use existing cells otherwise output will be earesed use new cells to write code

# %% [markdown]
# #### Import Related Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# download data set from this link
#
# [h1b.csv](https://drive.google.com/file/d/1GHotByxQaCXKPAuNI7dqIMiOMdmnkOzN/view?usp=sharing)

# %% [markdown]
# ### read csv in Pandas DataFrame

# %%
df=pd.read_csv('h1b.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          CASE_STATUS
# 0           1  CERTIFIED-WITHDRAWN  \
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME
# 0                             UNIVERSITY OF MICHIGAN  \
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW  \
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE
# 0                  N          36067.0  2016.0      ANN ARBOR, MICHIGAN  \
# 1                  Y         242674.0  2016.0             PLANO, TEXAS
# 2                  Y         193066.0  2016.0  JERSEY CITY, NEW JERSEY
# 3                  Y         220314.0  2016.0         DENVER, COLORADO
# 4                  Y         157518.4  2016.0      ST. LOUIS, MISSOURI
#
#           lon        lat
# 0  -83.743038  42.280826
# 1  -96.698886  33.019843
# 2  -74.077642  40.728158
# 3 -104.990251  39.739236
# 4  -90.199404  38.627003

# %% [markdown]
# ### show columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### delete 'unnamed:0'  column from data set

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ## check no of rows in data frame

# %%
df.shape[0]
# Out:
# 3002458

# %% [markdown]
# ## Drop All rows which has any NA value and show first 5 rows after this operation

# %%
df.isna().sum()
df.dropna(inplace=True)

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN  \
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW  \
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE
# 0                  N          36067.0  2016.0      ANN ARBOR, MICHIGAN  \
# 1                  Y         242674.0  2016.0             PLANO, TEXAS
# 2                  Y         193066.0  2016.0  JERSEY CITY, NEW JERSEY
# 3                  Y         220314.0  2016.0         DENVER, COLORADO
# 4                  Y         157518.4  2016.0      ST. LOUIS, MISSOURI
#
#           lon        lat
# 0  -83.743038  42.280826
# 1  -96.698886  33.019843
# 2  -74.077642  40.728158
# 3 -104.990251  39.739236
# 4  -90.199404  38.627003

# %% [markdown]
# ## reset index and check how many rows you have

# %%
df.reset_index()
# Out:
#            index          CASE_STATUS
# 0              0  CERTIFIED-WITHDRAWN  \
# 1              1  CERTIFIED-WITHDRAWN
# 2              2  CERTIFIED-WITHDRAWN
# 3              3  CERTIFIED-WITHDRAWN
# 4              4            WITHDRAWN
# ...          ...                  ...
# 2877760  3002440            WITHDRAWN
# 2877761  3002441            WITHDRAWN
# 2877762  3002442            WITHDRAWN
# 2877763  3002443            WITHDRAWN
# 2877764  3002444            WITHDRAWN
#
#                                              EMPLOYER_NAME
# 0                                   UNIVERSITY OF MICHIGAN  \
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 2877760                               ORACLE AMERICA, INC.
# 2877761                                 B & D DENTAL CORP.
# 2877762                  MEDTECH STAFFING & SOLUTIONS, INC
# 2877763                            LARSEN & TOUBRO LIMITED
# 2877764                            LARSEN & TOUBRO LIMITED
#
#                                                   SOC_NAME
# 0                            BIOCHEMISTS AND BIOPHYSICISTS  \
# 1                                         CHIEF EXECUTIVES
# 2                                         CHIEF EXECUTIVES
# 3                                         CHIEF EXECUTIVES
# 4                                         CHIEF EXECUTIVES
# ...                                                    ...
# 2877760                  Software Developers, Applications
# 2877761                               Materials Scientists
# 2877762  Market Research Analysts and Marketing Special...
# 2877763                Commercial and Industrial Designers
# 2877764                Commercial and Industrial Designers
#
#                                         JOB_TITLE FULL_TIME_POSITION
# 0                    POSTDOCTORAL RESEARCH FELLOW                  N  \
# 1                         CHIEF OPERATING OFFICER                  Y
# 2                           CHIEF PROCESS OFFICER                  Y
# 3                     REGIONAL PRESIDEN, AMERICAS                  Y
# 4                    PRESIDENT MONGOLIA AND INDIA                  Y
# ...                                           ...                ...
# 2877760  SOFTWARE ENGINEER (SOFTWARE DEVELOPER 2)                  Y
# 2877761                       MATERIALS SCIENTIST                  N
# 2877762                   MARKET RESEARCH ANALYST                  Y
# 2877763                           DESIGN ENGINEER                  Y
# 2877764                           DESIGN ENGINEER                  Y
#
#          PREVAILING_WAGE    YEAR                    WORKSITE         lon
# 0                36067.0  2016.0         ANN ARBOR, MICHIGAN  -83.743038  \
# 1               242674.0  2016.0                PLANO, TEXAS  -96.698886
# 2               193066.0  2016.0     JERSEY CITY, NEW JERSEY  -74.077642
# 3               220314.0  2016.0            DENVER, COLORADO -104.990251
# 4               157518.4  2016.0         ST. LOUIS, MISSOURI  -90.199404
# ...                  ...     ...                         ...         ...
# 2877760          64800.0  2011.0  REDWOOD SHORES, CALIFORNIA -122.245536
# 2877761          70553.6  2011.0           WEST VALLEY, UTAH -112.001050
# 2877762          33800.0  2011.0                 AKRON, OHIO  -81.519005
# 2877763          59800.0  2011.0   CHELMSFORD, MASSACHUSETTS  -71.367284
# 2877764          59800.0  2011.0   CHELMSFORD, MASSACHUSETTS  -71.367284
#
#                lat
# 0        42.280826
# 1        33.019843
# 2        40.728158
# 3        39.739236
# 4        38.627003
# ...            ...
# 2877760  37.536413
# 2877761  40.691613
# 2877762  41.081445
# 2877763  42.599814
# 2877764  42.599814
#
# [2877765 rows x 11 columns]

# %%
df.shape[0]
# Out:
# 2877765

# %% [markdown]
# ## Write a code to find out top 15 hiring company (Employer Name)

# %%
df['EMPLOYER_NAME'].value_counts().head()
# Out:
# EMPLOYER_NAME
# INFOSYS LIMITED                      130257
# TATA CONSULTANCY SERVICES LIMITED     64273
# WIPRO LIMITED                         45673
# DELOITTE CONSULTING LLP               35999
# IBM INDIA PRIVATE LIMITED             33585
# Name: count, dtype: int64

# %%
d=df['EMPLOYER_NAME'].value_counts()[:15].reset_index()
fig,ax=plt.subplots()
ax=sns.barplot(data=d,x='EMPLOYER_NAME',y='count')
ax.set_xticklabels(d['EMPLOYER_NAME'],rotation=90)
ax.set_xlabel('Companies')
ax.set_ylabel('Frequency')
ax.set_title('Top 15 Hiring Company')
plt.show()

# %% [markdown]
# ### Top 15 companies which provide highest PREVALING WAGE

# %%
df["PREVAILING_WAGE"].value_counts().head(5)
# Out:
# PREVAILING_WAGE
# 60000.0    10185
# 55245.0     6745
# 62566.0     6480
# 58053.0     5683
# 52499.0     5492
# Name: count, dtype: int64

# %% [markdown]
# ##### Average PREVAILING WAGE

# %%
df['PREVAILING_WAGE'].mean()
# Out:
# 145166.64888401062

# %%
d=df.groupby('EMPLOYER_NAME')['PREVAILING_WAGE'].mean().sort_values(ascending=False).head(15).reset_index()
fig,ax=plt.subplots()
ax=sns.barplot(data=d,x='EMPLOYER_NAME',y='PREVAILING_WAGE')
ax.set_xticklabels(d['EMPLOYER_NAME'],rotation=90)
ax.set_xlabel('Employee_Name')
ax.set_ylabel('Wages')
plt.show()

# %% [markdown]
# ### Top 20 WORKSITE

# %%
d=df['WORKSITE'].value_counts()[:20]
d
# Out:
# WORKSITE
# NEW YORK, NEW YORK            190863
# HOUSTON, TEXAS                 83385
# SAN FRANCISCO, CALIFORNIA      62457
# ATLANTA, GEORGIA               52008
# CHICAGO, ILLINOIS              51167
# SAN JOSE, CALIFORNIA           49582
# SUNNYVALE, CALIFORNIA          34968
# DALLAS, TEXAS                  31509
# BOSTON, MASSACHUSETTS          31336
# REDMOND, WASHINGTON            30574
# CHARLOTTE, NORTH CAROLINA      30176
# IRVING, TEXAS                  29316
# MOUNTAIN VIEW, CALIFORNIA      29245
# SAN DIEGO, CALIFORNIA          28656
# SANTA CLARA, CALIFORNIA        27945
# JERSEY CITY, NEW JERSEY        26822
# SEATTLE, WASHINGTON            26745
# AUSTIN, TEXAS                  26695
# LOS ANGELES, CALIFORNIA        26393
# PHILADELPHIA, PENNSYLVANIA     24104
# Name: count, dtype: int64

# %%
d=df['WORKSITE'].value_counts().head(20).reset_index()
fig,ax=plt.subplots()
ax=sns.barplot(data=d,x='WORKSITE',y='count')
ax.set_xticklabels(d['WORKSITE'],rotation=90)
ax.set_xlabel('WORKSITE')
ax.set_ylabel('Freq')
plt.show()

# %% [markdown]
# ### head of Worksite Column

# %%
df['WORKSITE'].head()
# Out:
# 0        ANN ARBOR, MICHIGAN
# 1               PLANO, TEXAS
# 2    JERSEY CITY, NEW JERSEY
# 3           DENVER, COLORADO
# 4        ST. LOUIS, MISSOURI
# Name: WORKSITE, dtype: object

# %% [markdown]
# ### Show Column Names

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### Apply a Function on DataFrame to gather only State Name from Worksite
#
#     eg. worksite name current -  SAN FRANCISCO, CALIFORNIA
#         worksite name after - CALIFORNIA
#
# **note**: there sholud not be any space at the begning or end of worksite name

# %%
df["WORKSITE"].unique()[:10]
# Out:
# array(['ANN ARBOR, MICHIGAN', 'PLANO, TEXAS', 'JERSEY CITY, NEW JERSEY',
#        'DENVER, COLORADO', 'ST. LOUIS, MISSOURI', 'MIAMI, FLORIDA',
#        'HOUSTON, TEXAS', 'SAN JOSE, CALIFORNIA', 'VIENNA, VIRGINIA',
#        'PITTSBURGH, PENNSYLVANIA'], dtype=object)

# %%
def get_state(worksite_name):
    return worksite_name.split(",")[-1].upper()

# %%
ans = df["WORKSITE"].apply(get_state)

# %%
df["WORKSITE"] = df["WORKSITE"].apply(lambda worksite: worksite.split(',')[1])

# %%
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN  \
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW  \
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR     WORKSITE         lon
# 0                  N          36067.0  2016.0     MICHIGAN  -83.743038  \
# 1                  Y         242674.0  2016.0        TEXAS  -96.698886
# 2                  Y         193066.0  2016.0   NEW JERSEY  -74.077642
# 3                  Y         220314.0  2016.0     COLORADO -104.990251
# 4                  Y         157518.4  2016.0     MISSOURI  -90.199404
#
#          lat
# 0  42.280826
# 1  33.019843
# 2  40.728158
# 3  39.739236
# 4  38.627003

# %% [markdown]
# **note:** if you view your analysis than you will find that 'MARIANA ISLANDS' worksite name is replaced with NA values

# %% [markdown]
# ### Replace all NA records in your Worksite Column with Value  'MARIANA ISLANDS'

# %%
df.loc[df["WORKSITE"]==" NA", "WORKSITE"] = 'MARIANA ISLANDS'

# %% [markdown]
# ### Print out how many unique Worksites are there

# %%
df['WORKSITE'].value_counts().head()
# Out:
# WORKSITE
#  CALIFORNIA    548539
#  TEXAS         286704
#  NEW YORK      282429
#  NEW JERSEY    206876
#  ILLINOIS      154843
# Name: count, dtype: int64

# %% [markdown]
# ##### show column names

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# #### Rename you column names as
#
#     {'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'}

# %%
df.rename(
    {'EMPLOYER_NAME':'EMPLOYER',
     'FULL_TIME_POSITION':'FULL_T',
     'PREVAILING_WAGE':'PREV_WAGE',
     'WORKSITE':'STATE',
     'lon':'LON',
     'lat':'LAT'},
    axis=1,
    inplace = True
)

# %% [markdown]
# #### Now Remove all Columns Except these columns
#
#     'CASE_STATUS','YEAR','STATE','SOC_NAME','JOB_TITLE','FULL_T','PREV_WAGE','EMPLOYER','LON',"LAT"

# %%
new_df = df.loc[:, ['STATE','EMPLOYER','PREV_WAGE','CASE_STATUS','YEAR','SOC_NAME','JOB_TITLE','FULL_T','LON',"LAT"]]

# %% [markdown]
# __show colnames__

# %%
new_df.columns
# Out:
# Index(['STATE', 'EMPLOYER', 'PREV_WAGE', 'CASE_STATUS', 'YEAR', 'SOC_NAME',
#        'JOB_TITLE', 'FULL_T', 'LON', 'LAT'],
#       dtype='object')

# %% [markdown]
# #### Perform These Operations
#
#     Precise LON and LAT columns upto 2 decimal palaces
#
#     Convert YEAR Column into String
#
#     Convert PREV_WAGE column into Integer

# %%
df["YEAR"] = df["YEAR"].astype(str)
df["PREV_WAGE"] = df["PREV_WAGE"].astype(int).round()

# %%
df["LAT"] = df["LAT"].round(2)
df["LON"] = df["LON"].round(2)

# %% [markdown]
# __show top 3 values to check above operations__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2877765 entries, 0 to 3002444
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   CASE_STATUS  object
#  1   EMPLOYER     object
#  2   SOC_NAME     object
#  3   JOB_TITLE    object
#  4   FULL_T       object
#  5   PREV_WAGE    int32
#  6   YEAR         object
#  7   STATE        object
#  8   LON          float64
#  9   LAT          float64
# dtypes: float64(2), int32(1), object(7)
# memory usage: 230.5+ MB

# %% [markdown]
# ### __show unique values of CASE_STATUS Column__

# %%
df["CASE_STATUS"].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %% [markdown]
# # Calculate the petitions distributions by status

# %%
s = df["CASE_STATUS"].unique()
a = df["CASE_STATUS"].value_counts()
return_list = list(pd.Series(a, s))
return_list
# Out:
# [195721, 84752, 2512114, 85161, 1, 1, 15]

# %%
from matplotlib.pyplot import pie,axis,show
import matplotlib as mpl

# %% [markdown]
# #### PETITIONS BY CASE STATUS

# %%
label = df["CASE_STATUS"].unique()
value = df["CASE_STATUS"].unique()
case_counts = df["CASE_STATUS"].value_counts().plot(kind="pie", labels=label, autopct="%.2f")
plt.show()

# %% [markdown]
# # Calculating the petitions distributions by year

# %%
year = df["YEAR"].value_counts()
s = list(year)
s.reverse()
s
# Out:
# [333625, 394267, 422427, 498027, 600120, 629299]

# %%
colors = ["green", "pink", "blue", "yellow", "purple", "red"]
df["YEAR"].value_counts()[::-1].plot(kind="bar", color=colors, figsize=(13, 3))
plt.title("Petitions distributions by year", fontsize=25, color="white")
plt.xlabel("YEAR", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# %%
sns.set_context("notebook",font_scale=1.0)
plt.figure(figsize=(13,3))
plt.title('petitions distributions by year')
sns.countplot(df['YEAR'])
# Out:
# <Axes: title={'center': 'petitions distributions by year'}, ylabel='count'>

# %%
denied = df[df.CASE_STATUS == 'DENIED']
len(denied)
# Out:
# 85161

# %%
# denied = f[f.CASE_STATUS == 'DENIED']
# len(denied)

# %%
del denied['CASE_STATUS']

# %%
denied = denied.reset_index()
denied.head(3)
# Out:
#    index              EMPLOYER          SOC_NAME
# 0     39       PARALLELS, INC.  CHIEF EXECUTIVES  \
# 1     47  RANCHO LA PUERTA LLC  CHIEF EXECUTIVES
# 2     95   BAKER & MCKENZIE PC  CHIEF EXECUTIVES
#
#                                            JOB_TITLE FULL_T  PREV_WAGE
# 0                            CHIEF EXECUTIVE OFFICER      Y     187200  \
# 1                                          PRESIDENT      Y     197683
# 2  PRINCIPAL (ATTORNEY) AND CHAIRMAN OF THE EXECU...      Y     226699
#
#      YEAR        STATE     LON    LAT
# 0  2016.0   WASHINGTON -122.22  47.48
# 1  2016.0   CALIFORNIA -117.16  32.72
# 2  2016.0     ILLINOIS  -87.63  41.88

# %%
denied_year_count = [0]* 6

# %%
df["CASE_STATUS"].value_counts()["DENIED"]
# Out:
# 85161

# %% [markdown]
# ### Denied PETITIONS DISTRIBUTION BY YEAR

# %%
df[(df["CASE_STATUS"]=="DENIED")]["YEAR"].value_counts().plot(kind="bar",title=("DENIED PETITIONS DISTRIBUTION BY YEAR"), figsize=(15, 3), color = ["red", "green", "yellow", "cyan", "purple", "pink"])

plt.show()

# %% [markdown]
# #### Denied % Rate By Year

# %%
p = df[["CASE_STATUS","YEAR"]]["YEAR"].value_counts()
s =df[(df["CASE_STATUS"]=="DENIED")]["YEAR"].value_counts()
DF = pd.DataFrame(p)
DF2 = pd.DataFrame(s)
new = pd.concat([DF, DF2], axis=1)
new.columns=["ALL", "DENIED"]
sf = new["DENIED"]/new["ALL"]*100
no = pd.DataFrame(sf)
no.columns = ["Denied Ratio %"]
no["Denied Ratio %"] = no["Denied Ratio %"].round(2)

no.T
# Out:
# YEAR            2016.0  2015.0  2014.0  2013.0  2012.0  2011.0
# Denied Ratio %    1.35    1.67    2.17     2.6    4.79    7.79

# %%
color = ["green",  "yellow", "cyan", "purple", "pink"]
no.plot(kind="bar", color = "purple", title=("Denied % Rate By Year"), figsize=(15, 3))
# Out:
# <Axes: title={'center': 'Denied % Rate By Year'}, xlabel='YEAR'>

# %% [markdown]
# ## Calculate the number of petitions filed by the States

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'YEAR', 'STATE', 'LON', 'LAT'],
#       dtype='object')

# %% [markdown]
# **unique stats sorted**

# %%
sts = list(df["STATE"].unique())
print(sts)
# Out:
# [' MICHIGAN', ' TEXAS', ' NEW JERSEY', ' COLORADO', ' MISSOURI', ' FLORIDA', ' CALIFORNIA', ' VIRGINIA', ' PENNSYLVANIA', ' WISCONSIN', ' ILLINOIS', ' DISTRICT OF COLUMBIA', ' NORTH CAROLINA', ' RHODE ISLAND', ' OHIO', ' WASHINGTON', ' GEORGIA', ' NEW YORK', ' INDIANA', ' MARYLAND', ' MASSACHUSETTS', ' NEVADA', ' NEW HAMPSHIRE', ' LOUISIANA', ' MINNESOTA', ' SOUTH CAROLINA', ' ARIZONA', ' TENNESSEE', ' HAWAII', ' UTAH', ' DELAWARE', 'MARIANA ISLANDS', ' KANSAS', ' CONNECTICUT', ' MAINE', ' OKLAHOMA', ' ARKANSAS', ' PUERTO RICO', ' ALASKA', ' IOWA', ' OREGON', ' KENTUCKY', ' NEBRASKA', ' NEW MEXICO', ' WEST VIRGINIA', ' SOUTH DAKOTA', ' NORTH DAKOTA', ' MISSISSIPPI', ' ALABAMA', ' VERMONT', ' IDAHO', ' WYOMING', ' MONTANA']

# %%
len(sts)
# Out:
# 53

# %%
fig, ax = plt.subplots(figsize=(25, 10))
ax=sns.barplot(x=df["STATE"].value_counts().sort_index().index, 
       y=df["STATE"].value_counts().sort_index().values)

# set plot title and axes labels
ax.set_title("Number of Records by State", fontsize=20)
ax.set_xlabel("State", fontsize=16)
ax.set_ylabel("Number of Records", fontsize=20)

# set x-tick labels rotation angle and font size
plt.xticks(rotation=90, fontsize=12)

# set y-tick font size
plt.yticks(fontsize=12)

# remove top and right spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# display the plot
plt.show()

# %% [markdown]
# # Number of petitions denied by the state

# %% [markdown]
# __total denied petitions__

# %%
denied = df[df.CASE_STATUS == 'DENIED']
len(denied)
# Out:
# 85161

# %%
fig, ax = plt.subplots(figsize=(25, 10))
ax=sns.barplot(x=denied["STATE"].value_counts().sort_index().index, 
       y=denied["STATE"].value_counts().sort_index().values)

ax.set_title("Denied by State", fontsize=20)
ax.set_xlabel("State", fontsize=16)
ax.set_ylabel("Denied of pentation", fontsize=20)

plt.xticks(rotation=90, fontsize=12)

plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# ## % Rate of Denied Petitions by State

# %% [markdown]
# #### Find out how many applied for Illinois State and how many how them are Denied

# %%
df['STATE']=df['STATE'].apply(lambda x : x.strip())

# %%
((df['STATE']=="ILLINOIS")&(df['CASE_STATUS']=="DENIED")).sum()
# Out:
# 3612

# %% [markdown]
# #### How Many People are Certified for Job title 'CHIEF PROCESS OFFICER'  who applied for state  Illinois

# %%
((df['CASE_STATUS']=="CERTIFIED")&(df['JOB_TITLE']=='CHIEF PROCESS OFFICER')&(df["STATE"]=="ILLINOIS")).sum()
# Out:
# 2

# %% [markdown]
# # Top 25 Job Titles

# %%
df['JOB_TITLE'].value_counts().head(25)
# Out:
# JOB_TITLE
# PROGRAMMER ANALYST             243357
# SOFTWARE ENGINEER              118897
# COMPUTER PROGRAMMER             68696
# SYSTEMS ANALYST                 60754
# SOFTWARE DEVELOPER              41875
# BUSINESS ANALYST                38781
# COMPUTER SYSTEMS ANALYST        34036
# TECHNOLOGY LEAD - US            28307
# SENIOR SOFTWARE ENGINEER        26617
# TECHNOLOGY ANALYST - US         26010
# ASSISTANT PROFESSOR             24436
# SENIOR CONSULTANT               24120
# CONSULTANT                      22643
# PROJECT MANAGER                 19015
# DATABASE ADMINISTRATOR          16108
# PHYSICAL THERAPIST              14203
# RESEARCH ASSOCIATE              13409
# COMPUTER PROGRAMMER ANALYST     13116
# ACCOUNTANT                      12934
# DEVELOPER                       12737
# ASSOCIATE                       12447
# ANALYST                         11644
# LEAD ENGINEER                   11012
# SENIOR SOFTWARE DEVELOPER       10031
# SYSTEMS ENGINEER - US           10020
# Name: count, dtype: int64

# %% [markdown]
# !!! Great Now Make Your Own Questions and Try to Answer Them !!
