# %%
import numpy as np
import pandas as pd

# %%
#read csv in Pandas DataFrame
df=pd.read_csv('h1b.csv')
df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# ...             ...                  ...
# 3002453     3002454                  NaN
# 3002454     3002455                  NaN
# 3002455     3002456                  NaN
# 3002456     3002457                  NaN
# 3002457     3002458                  NaN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# ...

# %%
#show columns
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
#delete 'unnamed:0' column from data set
df.drop(columns='Unnamed: 0',inplace=True)
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# check no of rows in data frame

# %%
## Drop All rows which has any NA value and show first 5 rows after this operation
df.dropna(inplace=True)
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %%
## reset index and check how many rows you have 
df.reset_index(drop=True,inplace=True)
len(df)
# Out:
# 2877765

# %% [markdown]
# ## Write a code to find out top 15 hiring company (Employer Name)

# %%
df['EMPLOYER_NAME'].value_counts().head(15)
# Out:
# INFOSYS LIMITED                                    130257
# TATA CONSULTANCY SERVICES LIMITED                   64273
# WIPRO LIMITED                                       45673
# DELOITTE CONSULTING LLP                             35999
# IBM INDIA PRIVATE LIMITED                           33585
# ACCENTURE LLP                                       33226
# MICROSOFT CORPORATION                               25551
# HCL AMERICA, INC.                                   22488
# ERNST & YOUNG U.S. LLP                              18094
# COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION     17322
# CAPGEMINI AMERICA INC                               16628
# GOOGLE INC.                                         16425
# LARSEN & TOUBRO INFOTECH LIMITED                    14318
# IGATE TECHNOLOGIES INC.                             12327
# IBM CORPORATION                                     11976
# Name: EMPLOYER_NAME, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 3),dpi=100)
plt.title(label='TOP 15 Hiring Company')
df['EMPLOYER_NAME'].value_counts().head(15).plot(kind='bar',color=['r','g','b','m','c'])
plt.show()

# %% [markdown]
# ### Top 15 companies which provide highest PREVALING WAGE

# %%
############################################################################################################################
df.groupby('EMPLOYER_NAME')['PREVAILING_WAGE'].median().sort_values(ascending=False)
# v
# Out:
# EMPLOYER_NAME
# BAALAAJEE INC.                            215109440.0
# OMPI OF AMERICA INC.                      212987840.0
# INNOBOX SYSTEMS                           172363360.0
# DEPARTMENT OF VETERANS AFFAIRS/NMVAHCS    134702089.5
# MANHATTAN SOFTWARE, INC.                  123907680.0
#                                              ...
# LEGACY INTERNATIONAL UNLIMITED LLC                0.0
# LOTUS SOFT CORPORATION                            0.0
# JONATHAN A KUIPERS PLLC                           0.0
# STOBI, LLC                                        0.0
# MCNAMARA LEGAL SERVICES, P.A.                     0.0
# Name: PREVAILING_WAGE, Length: 214982, dtype: float64

# %%
df['PREVAILING_WAGE'].mean()
# Out:
# 145166.64888401062

# %%
plt.figure(dpi=100)
plt.title('Top 15 companies highest PREVALING WAGE')
df.groupby('EMPLOYER_NAME')['PREVAILING_WAGE'].mean().sort_values(ascending=False).head(15).plot(kind='bar',color=['r','g','b','m','c'])
plt.show()

# %% [markdown]
# ### Top 20 WORKSITE

# %%
df['WORKSITE'].value_counts().head(20)
# Out:
# NEW YORK, NEW YORK            190863
# HOUSTON, TEXAS                 83385
# SAN FRANCISCO, CALIFORNIA      62457
# ATLANTA, GEORGIA               52008
# CHICAGO, ILLINOIS              51167
# SAN JOSE, CALIFORNIA           49582
# SUNNYVALE, CALIFORNIA          34968
# DALLAS, TEXAS                  31509
# BOSTON, MASSACHUSETTS          31336
# REDMOND, WASHINGTON            30574
# CHARLOTTE, NORTH CAROLINA      30176
# IRVING, TEXAS                  29316
# MOUNTAIN VIEW, CALIFORNIA      29245
# SAN DIEGO, CALIFORNIA          28656
# SANTA CLARA, CALIFORNIA        27945
# JERSEY CITY, NEW JERSEY        26822
# SEATTLE, WASHINGTON            26745
# AUSTIN, TEXAS                  26695
# LOS ANGELES, CALIFORNIA        26393
# PHILADELPHIA, PENNSYLVANIA     24104
# Name: WORKSITE, dtype: int64

# %%
plt.title('Top 20 Worksite')
df['WORKSITE'].value_counts().head(20).plot(kind='bar',color=['r','g','b','m','c'])
# Out:
# <AxesSubplot:title={'center':'Top 20 Worksite'}>

# %% [markdown]
# ### head of Worksite Column

# %%
df['WORKSITE'].head()
# Out:
# 0        ANN ARBOR, MICHIGAN
# 1               PLANO, TEXAS
# 2    JERSEY CITY, NEW JERSEY
# 3           DENVER, COLORADO
# 4        ST. LOUIS, MISSOURI
# Name: WORKSITE, dtype: object

# %% [markdown]
# ### Show Column Names

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### Apply a Function on DataFrame to gather only State Name from Worksite
#
#     eg. worksite name current -  SAN FRANCISCO, CALIFORNIA
#         worksite name after - CALIFORNIA
#
# **note**: there sholud not be any space at the begning or end of worksite name

# %%
df['WORKSITE']
# Out:
# 0                 ANN ARBOR, MICHIGAN
# 1                        PLANO, TEXAS
# 2             JERSEY CITY, NEW JERSEY
# 3                    DENVER, COLORADO
# 4                 ST. LOUIS, MISSOURI
#                       ...
# 2877760    REDWOOD SHORES, CALIFORNIA
# 2877761             WEST VALLEY, UTAH
# 2877762                   AKRON, OHIO
# 2877763     CHELMSFORD, MASSACHUSETTS
# 2877764     CHELMSFORD, MASSACHUSETTS
# Name: WORKSITE, Length: 2877765, dtype: object

# %%
df['WORKSITE']=df['WORKSITE'].apply(lambda x:x.split(',')[-1].strip())
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 2877760            WITHDRAWN
# 2877761            WITHDRAWN
# 2877762            WITHDRAWN
# 2877763            WITHDRAWN
# 2877764            WITHDRAWN
#
#                                              EMPLOYER_NAME  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 2877760                               ORACLE AMERICA, INC.
# 2877761                                 B & D DENTAL CORP.
# 2877762                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %% [markdown]
# **note:** if you view your analysis than you will find that 'MARIANA ISLANDS' worksite name is replaced with NA values

# %% [markdown]
# ### Replace all NA records in your Worksite Column with Value  'MARIANA ISLANDS'

# %%
df['WORKSITE'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WORKSITE'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ### Print out how many unique Worksites are there

# %%
len(df["WORKSITE"].unique())
# Out:
# 53

# %% [markdown]
# ##### show column names

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# #### Rename you column names as
#
#     {'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'}

# %%
# col={'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'}
df=df.rename(columns={'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'})
df
# Out:
#                  CASE_STATUS  \
# 0        CERTIFIED-WITHDRAWN
# 1        CERTIFIED-WITHDRAWN
# 2        CERTIFIED-WITHDRAWN
# 3        CERTIFIED-WITHDRAWN
# 4                  WITHDRAWN
# ...                      ...
# 2877760            WITHDRAWN
# 2877761            WITHDRAWN
# 2877762            WITHDRAWN
# 2877763            WITHDRAWN
# 2877764            WITHDRAWN
#
#                                                   EMPLOYER  \
# 0                                   UNIVERSITY OF MICHIGAN
# 1                                   GOODMAN NETWORKS, INC.
# 2                                PORTS AMERICA GROUP, INC.
# 3        GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                PEABODY INVESTMENTS CORP.
# ...                                                    ...
# 2877760                               ORACLE AMERICA, INC.
# 2877761                                 B & D DENTAL CORP.
# 2877762                  MEDTECH STAFFING & SOLUTIONS, INC
# ...

# %% [markdown]
# #### Now Remove all Columns Except these columns
#
#     'CASE_STATUS','YEAR','STATE','SOC_NAME','JOB_TITLE','FULL_T','PREV_WAGE','EMPLOYER','LON',"LAT"

# %%
# NOTE: There is already a 10 columns according to questins there is no colums we need to remove

# %% [markdown]
# __show colnames__

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'YEAR', 'STATE', 'LON', 'LAT'],
#       dtype='object')

# %% [markdown]
# #### Perform These Operations
#
#     Precise LON and LAT columns upto 2 decimal palaces
#
#     Convert YEAR Column into String
#
#     Convert PREV_WAGE column into Integer

# %%
df['LON']=df["LON"].round(2)
df["LAT"]=df['LAT'].round(2)
df['YEAR']=df["YEAR"].astype(str)
df['PREV_WAGE']=df["PREV_WAGE"].astype(int)

# %% [markdown]
# __show top 3 values to check above operations__

# %%
df.head(3)
# Out:
#            CASE_STATUS                   EMPLOYER  \
# 0  CERTIFIED-WITHDRAWN     UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN     GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN  PORTS AMERICA GROUP, INC.
#
#                         SOC_NAME                     JOB_TITLE FULL_T  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW      N
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER      Y
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER      Y
#
#    PREV_WAGE    YEAR       STATE    LON    LAT
# 0      36067  2016.0    MICHIGAN -83.74  42.28
# 1     242674  2016.0       TEXAS -96.70  33.02
# 2     193066  2016.0  NEW JERSEY -74.08  40.73

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2877765 entries, 0 to 2877764
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   CASE_STATUS  object
#  1   EMPLOYER     object
#  2   SOC_NAME     object
#  3   JOB_TITLE    object
#  4   FULL_T       object
#  5   PREV_WAGE    int32
#  6   YEAR         object
#  7   STATE        object
#  8   LON          float64
#  9   LAT          float64
# dtypes: float64(2), int32(1), object(7)
# memory usage: 208.6+ MB

# %% [markdown]
# ### __show unique values of CASE_STATUS Column__

# %%
df["CASE_STATUS"].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %% [markdown]
# # Calculate the petitions distributions by status

# %%
df['CASE_STATUS'].value_counts()
# Out:
# CERTIFIED                                             2512114
# CERTIFIED-WITHDRAWN                                    195721
# DENIED                                                  85161
# WITHDRAWN                                               84752
# PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED         15
# REJECTED                                                    1
# INVALIDATED                                                 1
# Name: CASE_STATUS, dtype: int64

# %% [markdown]
# #### PETITIONS BY CASE STATUS

# %%
import matplotlib.pyplot as plt
selected=['CERTIFIED','DENIED','CERTIFIED-WITHDRAWN','WITHDRAWN']
df_selected=df[df['CASE_STATUS'].isin(selected)]
status=df_selected['CASE_STATUS'].value_counts()
plt.pie(status,labels=selected,shadow=True,colors=['green','red','blue','orange'])
plt.title('PETITIONS BY CASE STATUS')
plt.show()

# %% [markdown]
# # Calculating the petitions distributions by year

# %%
df.groupby('YEAR')['CASE_STATUS'].count()
# Out:
# YEAR
# 2011.0    333625
# 2012.0    394267
# 2013.0    422427
# 2014.0    498027
# 2015.0    600120
# 2016.0    629299
# Name: CASE_STATUS, dtype: int64

# %%
plt.figure(figsize=(13,3),dpi=100)
df.groupby('YEAR')['CASE_STATUS'].count().plot(kind='bar',color=['green','pink','red','orange','salmon','blue'])
plt.title('PETITIONS DISTRIBUTIOB BY YEAR')
plt.show()

# %%
denied=df[df['CASE_STATUS']=='DENIED']
len(denied)
# Out:
# 85161

# %%
del denied['CASE_STATUS']

# %%
# denied=denied.reset_index()

# %%
denied.head(3)
# Out:
#                 EMPLOYER          SOC_NAME  \
# 37       PARALLELS, INC.  CHIEF EXECUTIVES
# 44  RANCHO LA PUERTA LLC  CHIEF EXECUTIVES
# 87   BAKER & MCKENZIE PC  CHIEF EXECUTIVES
#
#                                             JOB_TITLE FULL_T  PREV_WAGE  \
# 37                            CHIEF EXECUTIVE OFFICER      Y     187200
# 44                                          PRESIDENT      Y     197683
# 87  PRINCIPAL (ATTORNEY) AND CHAIRMAN OF THE EXECU...      Y     226699
#
#       YEAR       STATE     LON    LAT
# 37  2016.0  WASHINGTON -122.22  47.48
# 44  2016.0  CALIFORNIA -117.16  32.72
# 87  2016.0    ILLINOIS  -87.63  41.88

# %% [markdown]
# ### Denied PETITIONS DISTRIBUTION BY YEAR

# %%
# denied_year_count = [0]* 6
# for i in range(0,6):
#     denied_year_count[i] = denied[denied.YEAR == YEAR[i]]['YEAR'].count()
# denied_year_count
denied['YEAR'].value_counts().tolist()
# Out:
# [25986, 18866, 10976, 10816, 10037, 8480]

# %%
plt.figure(figsize=(13,3),dpi=100)
denied['YEAR'].value_counts().plot(kind='bar',color=['green','pink','red','orange','salmon','blue'])
plt.title('Denied PETITIONS DISTRIBUTION BY YEAR')
plt.show()

# %%
##########################################################################################################################
result=(denied['YEAR'].value_counts()/df['YEAR'].value_counts())*100
result
# Out:
# 2011.0    7.788985
# 2012.0    4.785082
# 2013.0    2.598319
# 2014.0    2.171770
# 2015.0    1.672499
# 2016.0    1.347531
# Name: YEAR, dtype: float64

# %%
plt.figure(figsize=(13,3),dpi=100)
result.plot(kind='bar',color=['green','pink','red','orange','salmon','blue'])
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'YEAR', 'STATE', 'LON', 'LAT'],
#       dtype='object')

# %% [markdown]
# ## Calculate the number of petitions filed by the States

# %%
df.groupby('STATE')['CASE_STATUS'].count()
# Out:
# STATE
# ALABAMA                   8644
# ALASKA                    1116
# ARIZONA                  40184
# ARKANSAS                 13775
# CALIFORNIA              548539
# COLORADO                 30231
# CONNECTICUT              48174
# DELAWARE                 17705
# DISTRICT OF COLUMBIA     22408
# FLORIDA                 100384
# GEORGIA                  99679
# HAWAII                    3157
# IDAHO                     3777
# ILLINOIS                154843
# INDIANA                  28230
# IOWA                     15143
# KANSAS                   12331
# KENTUCKY                 10968
# LOUISIANA                10043
# MAINE                     3132
# MARYLAND                 53145
# MASSACHUSETTS           112659
# MICHIGAN                 77868
# MINNESOTA                45864
# MISSISSIPPI               2686
# MISSOURI                 32737
# MONTANA                    644
# NA                        3069
# NEBRASKA                  8600
# NEVADA                    7004
# ...

# %%
len(df['STATE'].unique())
# Out:
# 53

# %%
plt.figure(figsize=(13,3),dpi=100)
df.groupby('STATE')['CASE_STATUS'].count().plot(kind='bar',color=['red','blue','yellow','salmon'])
plt.title('FIELD PETITIONS BY STATE')
# Out:
# Text(0.5, 1.0, 'FIELD PETITIONS BY STATE')

# %% [markdown]
# # Number of petitions denied by the state

# %%
len(df[df["CASE_STATUS"]=='DENIED'])
# Out:
# 85161

# %%
plt.figure(figsize=(13,3),dpi=100)
df[df['CASE_STATUS']=='DENIED'].groupby('STATE')['CASE_STATUS'].count().plot(kind='bar',color=['green','blue','yellow','salmon'])
plt.title('PETITIONS DENIED BY STATE')
# Out:
# Text(0.5, 1.0, 'PETITIONS DENIED BY STATE')

# %%
############################################################################################################################
s=df[df['CASE_STATUS']=='DENIED'].groupby('STATE')['CASE_STATUS'].count()

# %% [markdown]
# #### Find out how many applied for Illinois State and how many how them are Denied

# %%
# s=df[df['STATE']=='ILLINOIS']
# s[s['CASE_STATUS']=='DENIED'].count()
((df['STATE']=="ILLINOIS")&(df['CASE_STATUS']=="DENIED")).sum()
# Out:
# 3612

# %% [markdown]
# #### How Many People are Certified for Job title 'CHIEF PROCESS OFFICER'  who applied for state  Illinois

# %%
((df['CASE_STATUS']=="CERTIFIED")&(df['JOB_TITLE']=='CHIEF PROCESS OFFICER')&(df["STATE"]=="ILLINOIS")).sum()
# Out:
# 2

# %% [markdown]
# # Top 25 Job Titles

# %%
df['JOB_TITLE'].value_counts().head(25)
# Out:
# PROGRAMMER ANALYST             243357
# SOFTWARE ENGINEER              118897
# COMPUTER PROGRAMMER             68696
# SYSTEMS ANALYST                 60754
# SOFTWARE DEVELOPER              41875
# BUSINESS ANALYST                38781
# COMPUTER SYSTEMS ANALYST        34036
# TECHNOLOGY LEAD - US            28307
# SENIOR SOFTWARE ENGINEER        26617
# TECHNOLOGY ANALYST - US         26010
# ASSISTANT PROFESSOR             24436
# SENIOR CONSULTANT               24120
# CONSULTANT                      22643
# PROJECT MANAGER                 19015
# DATABASE ADMINISTRATOR          16108
# PHYSICAL THERAPIST              14203
# RESEARCH ASSOCIATE              13409
# COMPUTER PROGRAMMER ANALYST     13116
# ACCOUNTANT                      12934
# DEVELOPER                       12737
# ASSOCIATE                       12447
# ANALYST                         11644
# LEAD ENGINEER                   11012
# SENIOR SOFTWARE DEVELOPER       10031
# SYSTEMS ENGINEER - US           10020
# ...

# %%
plt.figure(figsize=(13,3),dpi=100)
df['JOB_TITLE'].value_counts().head(25).plot(kind='bar',color=['blue','green','salmon','red','yellow','purple'])
plt.title('TOP 25 JON TITLES')
plt.show()
